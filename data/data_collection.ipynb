# %%
# libraries
import pandas as pd
import numpy as np
import os
import billboard
import re
import ast
from dotenv import load_dotenv
from lyricsgenius import Genius

# %%
# load in environment variables
load_dotenv()
genius_token = os.getenv('GENIUS_TOKEN')

# %%
# writing a regex function for breaking up the artist format to match the Kaggle database
# input: 
    # artist: string
# returns
    # artist_list: a list of strings containing the artist(s)

def artist_regex(artist_str):
    artist_list = re.split(r'\s*(Featuring|&|,)\s*', artist_str)
    artist_list = [artist.strip() for artist in artist_list if artist.strip() not in ['Featuring', 'ft', '&', 'and' ',']]

    if len(artist_list) == 1: # solo artist case
        return artist_list[0]
    
    return artist_list

# %%
# call for the billboard 100s from 2010-2023
chart_data_list = []
years = ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']

for y in years:
    chart = billboard.ChartData('hot-100-songs', year=y)

    for song in chart:
        chart_data_list.append({
            'name': song.title,
            'artists': artist_regex(song.artist),
            'Performer': song.artist,
            'year': int(y)
        })


chart_data = pd.DataFrame(chart_data_list)
chart_data['artists'] = chart_data['artists'].apply(str)
chart_data.head()
# Out:
#                name                       artists  \
# 0           TiK ToK                         Ke$ha
# 1      Need You Now               Lady Antebellum
# 2  Hey, Soul Sister                         Train
# 3  California Gurls  ['Katy Perry', 'Snoop Dogg']
# 4               OMG        ['Usher', 'will.i.am']
#
#                          Performer  year
# 0                            Ke$ha  2010
# 1                  Lady Antebellum  2010
# 2                            Train  2010
# 3  Katy Perry Featuring Snoop Dogg  2010
# 4        Usher Featuring will.i.am  2010

# %%
chart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1398 entries, 0 to 1397
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       1398 non-null   object
#  1   artists    1398 non-null   object
#  2   Performer  1398 non-null   object
#  3   year       1398 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 43.8+ KB

# %%
chart_data = chart_data.replace("Ke$ha", "Kesha")
chart_data
# Out:
#                               name                       artists  \
# 0                          TiK ToK                         Kesha
# 1                     Need You Now               Lady Antebellum
# 2                 Hey, Soul Sister                         Train
# 3                 California Gurls  ['Katy Perry', 'Snoop Dogg']
# 4                              OMG        ['Usher', 'will.i.am']
# ...                            ...                           ...
# 1393  Bzrp Music Sessions, Vol. 53       ['Bizarrap', 'Shakira']
# 1394                      Meltdown     ['Travis Scott', 'Drake']
# 1395      Put It On Da Floor Again          ['Latto', 'Cardi B']
# 1396                   Bloody Mary                     Lady Gaga
# 1397          Watermelon Moonshine                 Lainey Wilson
#
#                             Performer  year
# 0                               Kesha  2010
# 1                     Lady Antebellum  2010
# 2                               Train  2010
# 3     Katy Perry Featuring Snoop Dogg  2010
# 4           Usher Featuring will.i.am  2010
# ...                               ...   ...
# 1393               Bizarrap & Shakira  2023
# 1394     Travis Scott Featuring Drake  2023
# 1395          Latto Featuring Cardi B  2023
# 1396                        Lady Gaga  2023
# 1397                    Lainey Wilson  2023
#
# [1398 rows x 4 columns]

# %%
# since the kaggle database has the artists in a string which is a list of strings, we need to convert it

def list_eval(str):
    try:
        return ast.literal_eval(str)
    except:
        return str

# %%
# pull kaggle datasets
df_kaggle_1 = pd.read_csv('kaggle_data/songs_with_attributes_and_lyrics.csv')
df_kaggle_2 = pd.read_csv('kaggle_data/Hot 100 Audio Features.csv')
df_kaggle_3 = pd.read_csv('kaggle_data/billboard_24years_lyrics_spotify.csv')

# %%
# merge the dataframes, left on the chart data
merged_df = chart_data.merge(df_kaggle_1, on=['name', 'artists'], how = 'left')

# drop some unneeded columns
merged_df = merged_df.drop(columns = ['id', 'album_name'])

merged_df
# Out:
#                           name                    artists  \
# 0                      TiK ToK                      Kesha
# 1                      TiK ToK                      Kesha
# 2                      TiK ToK                      Kesha
# 3                 Need You Now            Lady Antebellum
# 4                 Need You Now            Lady Antebellum
# ...                        ...                        ...
# 2077                  Meltdown  ['Travis Scott', 'Drake']
# 2078  Put It On Da Floor Again       ['Latto', 'Cardi B']
# 2079               Bloody Mary                  Lady Gaga
# 2080               Bloody Mary                  Lady Gaga
# 2081      Watermelon Moonshine              Lainey Wilson
#
#                          Performer  year  danceability  energy  key  loudness  \
# 0                            Kesha  2010         0.755   0.837    2    -2.718
# 1                            Kesha  2010         0.755   0.832    2    -2.741
# 2                            Kesha  2010         0.737   0.839    2    -2.028
# 3                  Lady Antebellum  2010         0.588   0.724    4    -4.379
# 4                  Lady Antebellum  2010         0.581   0.717    4    -4.433
# ...                            ...   ...           ...     ...  ...       ...
# 2077  Travis Scott Featuring Drake  2023           NaN     NaN  NaN       NaN
# 2078       Latto Featuring Cardi B  2023           NaN     NaN  NaN       NaN
# 2079                     Lady Gaga  2023         0.584   0.638    9    -6.437
# 2080                     Lady Gaga  2023         0.584   0.638    9    -6.437
# 2081                 Lainey Wilson  2023         0.739   0.413    1    -6.709
#
#      mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0       0       0.1420        0.0991          0.000000     0.289    0.714
# 1       0       0.1160        0.0746          0.000001     0.291    0.735
# 2       0       0.1700        0.1030          0.000000     0.319    0.718
# 3       1       0.0315        0.0348          0.000095     0.239    0.377
# 4       1       0.0318        0.0298          0.000186     0.243    0.316
# ...   ...          ...           ...               ...       ...      ...
# 2077  NaN          NaN           NaN               NaN       NaN      NaN
# 2078  NaN          NaN           NaN               NaN       NaN      NaN
# 2079    0       0.0302        0.0134          0.000003     0.101    0.456
# 2080    0       0.0302        0.0134          0.000003     0.101    0.456
# 2081    1       0.0282        0.4700          0.000025     0.131    0.649
#
#         tempo  duration_ms                                             lyrics
# 0     120.028     199693.0  Wake up in the morning feelin' like P. Diddy (...
# 1     120.032     199693.0  Wake up in the morning feelin' like P. Diddy (...
# 2     120.042     200187.0  Wake up in the morning feelin' like P. Diddy (...
# 3     107.986     236787.0  Picture perfect memories, scattered all around...
# 4     107.884     236440.0  Picture perfect memories, scattered all around...
# ...       ...          ...                                                ...
# 2077      NaN          NaN                                                NaN
# 2078      NaN          NaN                                                NaN
# 2079   99.970     244760.0  Money\n ♪\n Oh\n Love is just a history that t...
# 2080   99.970     244760.0  Money\n ♪\n Oh\n Love is just a history that t...
# 2081  139.921     208853.0  It was right after senior year\n Just before t...
#
# [2082 rows x 17 columns]

# %%
# drop some unnneded columns before merging
df_kaggle_2 = df_kaggle_2.drop(columns=['index', 'SongID', 'spotify_track_id', 'spotify_track_preview_url', 
                          'spotify_track_explicit','spotify_track_album', 'time_signature', 
                          'spotify_track_popularity'])
df_kaggle_2
# Out:
#                                           Performer  \
# 0                                Bill Black's Combo
# 1                                        Augie Rios
# 2                                     Andy Williams
# 3                                      Sandy Nelson
# 4                                    Britney Spears
# ...                                             ...
# 29498  Lil Tjay Featuring Fivio Foreign & Pop Smoke
# 29499                                        Future
# 29500                Lil' Boosie Featuring Yung Joc
# 29501               Herb Alpert & The Tijuana Brass
# 29502                                            K7
#
#                                                    Song  \
# 0                          -twistin'-White Silver Sands
# 1      ¿Dònde Està Santa Claus? (Where Is Santa Claus?)
# 2                             ......And Roses And Roses
# 3                          ...And Then There Were Drums
# 4                                 ...Baby One More Time
# ...                                                 ...
# 29498                                          Zoo York
# 29499                                              Zoom
# 29500                                              Zoom
# 29501                                   Zorba The Greek
# 29502                                        Zunga Zeng
#
#                                            spotify_genre  \
# 0                                                     []
# 1                                            ['novelty']
# 2      ['adult standards', 'brill building pop', 'eas...
# 3       ['rock-and-roll', 'space age pop', 'surf music']
# 4                  ['dance pop', 'pop', 'post-teen pop']
# ...                                                  ...
# 29498                                                NaN
# 29499  ['atl hip hop', 'hip hop', 'pop rap', 'rap', '...
# 29500          ['baton rouge rap', 'deep southern trap']
# 29501    ['adult standards', 'easy listening', 'lounge']
# 29502                                      ['freestyle']
#
#        spotify_track_duration_ms  danceability  energy   key  loudness  mode  \
# 0                            NaN           NaN     NaN   NaN       NaN   NaN
# 1                            NaN           NaN     NaN   NaN       NaN   NaN
# 2                       166106.0         0.154   0.185   5.0   -14.063   1.0
# 3                       172066.0         0.588   0.672  11.0   -17.278   0.0
# 4                       211066.0         0.759   0.699   0.0    -5.745   0.0
# ...                          ...           ...     ...   ...       ...   ...
# 29498                        NaN           NaN     NaN   NaN       NaN   NaN
# 29499                   278429.0         0.852   0.438   9.0    -7.673   1.0
# 29500                        NaN           NaN     NaN   NaN       NaN   NaN
# 29501                   264853.0         0.531   0.642   5.0   -12.702   1.0
# 29502                   273000.0         0.846   0.657   1.0    -9.642   1.0
#
#        speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0              NaN           NaN               NaN       NaN      NaN      NaN
# 1              NaN           NaN               NaN       NaN      NaN      NaN
# 2           0.0315       0.91100          0.000267    0.1120    0.150   83.969
# 3           0.0361       0.00256          0.745000    0.1450    0.801  121.962
# 4           0.0307       0.20200          0.000131    0.4430    0.907   92.960
# ...            ...           ...               ...       ...      ...      ...
# 29498          NaN           NaN               NaN       NaN      NaN      NaN
# 29499       0.4260       0.01450          0.000000    0.2630    0.627  150.945
# 29500          NaN           NaN               NaN       NaN      NaN      NaN
# 29501       0.3230       0.15400          0.279000    0.0584    0.192   82.107
# 29502       0.1400       0.04780          0.000363    0.0392    0.619  103.743
#
# [29503 rows x 15 columns]

# %%
# do another merge
merged_df_2 = merged_df.merge(df_kaggle_2, left_on=['name', 'Performer'], right_on= ['Song', 'Performer'], 
                how = 'left', suffixes=['_df1', '_df2'])
merged_df_2
# Out:
#                           name                    artists  \
# 0                      TiK ToK                      Kesha
# 1                      TiK ToK                      Kesha
# 2                      TiK ToK                      Kesha
# 3                 Need You Now            Lady Antebellum
# 4                 Need You Now            Lady Antebellum
# ...                        ...                        ...
# 2297                  Meltdown  ['Travis Scott', 'Drake']
# 2298  Put It On Da Floor Again       ['Latto', 'Cardi B']
# 2299               Bloody Mary                  Lady Gaga
# 2300               Bloody Mary                  Lady Gaga
# 2301      Watermelon Moonshine              Lainey Wilson
#
#                          Performer  year  danceability_df1  energy_df1  \
# 0                            Kesha  2010             0.755       0.837
# 1                            Kesha  2010             0.755       0.832
# 2                            Kesha  2010             0.737       0.839
# 3                  Lady Antebellum  2010             0.588       0.724
# 4                  Lady Antebellum  2010             0.581       0.717
# ...                            ...   ...               ...         ...
# 2297  Travis Scott Featuring Drake  2023               NaN         NaN
# 2298       Latto Featuring Cardi B  2023               NaN         NaN
# 2299                     Lady Gaga  2023             0.584       0.638
# 2300                     Lady Gaga  2023             0.584       0.638
# 2301                 Lainey Wilson  2023             0.739       0.413
#
#      key_df1  loudness_df1 mode_df1  speechiness_df1  ...  energy_df2  \
# 0          2        -2.718        0           0.1420  ...         NaN
# 1          2        -2.741        0           0.1160  ...         NaN
# 2          2        -2.028        0           0.1700  ...         NaN
# 3          4        -4.379        1           0.0315  ...       0.622
# 4          4        -4.433        1           0.0318  ...       0.622
# ...      ...           ...      ...              ...  ...         ...
# 2297     NaN           NaN      NaN              NaN  ...         NaN
# 2298     NaN           NaN      NaN              NaN  ...         NaN
# 2299       9        -6.437        0           0.0302  ...         NaN
# 2300       9        -6.437        0           0.0302  ...         NaN
# 2301       1        -6.709        1           0.0282  ...         NaN
#
#       key_df2  loudness_df2  mode_df2  speechiness_df2  acousticness_df2  \
# 0         NaN           NaN       NaN              NaN               NaN
# 1         NaN           NaN       NaN              NaN               NaN
# 2         NaN           NaN       NaN              NaN               NaN
# 3         4.0        -5.535       1.0           0.0303            0.0927
# 4         4.0        -5.535       1.0           0.0303            0.0927
# ...       ...           ...       ...              ...               ...
# 2297      NaN           NaN       NaN              NaN               NaN
# 2298      NaN           NaN       NaN              NaN               NaN
# 2299      NaN           NaN       NaN              NaN               NaN
# 2300      NaN           NaN       NaN              NaN               NaN
# 2301      NaN           NaN       NaN              NaN               NaN
#
#      instrumentalness_df2 liveness_df2 valence_df2  tempo_df2
# 0                     NaN          NaN         NaN        NaN
# 1                     NaN          NaN         NaN        NaN
# 2                     NaN          NaN         NaN        NaN
# 3                0.000636          0.2       0.231    107.943
# 4                0.000636          0.2       0.231    107.943
# ...                   ...          ...         ...        ...
# 2297                  NaN          NaN         NaN        NaN
# 2298                  NaN          NaN         NaN        NaN
# 2299                  NaN          NaN         NaN        NaN
# 2300                  NaN          NaN         NaN        NaN
# 2301                  NaN          NaN         NaN        NaN
#
# [2302 rows x 31 columns]

# %%
# combine audio feature columns with combine first
features = [
    'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'
]

# loop through the featyres
for feature in features:
    merged_df_2[feature] = merged_df_2[f'{feature}_df1'].combine_first(merged_df_2[f'{feature}_df2'])

# some additional columns that don't follow the pattern
merged_df_2['duration_ms_new'] = merged_df_2['duration_ms'].combine_first(merged_df_2['spotify_track_duration_ms'])

merged_df_2.drop(columns = ['danceability_df1',
       'energy_df1', 'key_df1', 'loudness_df1', 'mode_df1', 'speechiness_df1',
       'acousticness_df1', 'instrumentalness_df1', 'liveness_df1',
       'valence_df1', 'tempo_df1', 'duration_ms', 'spotify_track_duration_ms', 'danceability_df2',
       'energy_df2', 'key_df2', 'loudness_df2', 'mode_df2', 'speechiness_df2',
       'acousticness_df2', 'instrumentalness_df2', 'liveness_df2',
       'valence_df2', 'tempo_df2', 'Song'], inplace = True)

merged_df_2
# Out:
#                           name                    artists  \
# 0                      TiK ToK                      Kesha
# 1                      TiK ToK                      Kesha
# 2                      TiK ToK                      Kesha
# 3                 Need You Now            Lady Antebellum
# 4                 Need You Now            Lady Antebellum
# ...                        ...                        ...
# 2297                  Meltdown  ['Travis Scott', 'Drake']
# 2298  Put It On Da Floor Again       ['Latto', 'Cardi B']
# 2299               Bloody Mary                  Lady Gaga
# 2300               Bloody Mary                  Lady Gaga
# 2301      Watermelon Moonshine              Lainey Wilson
#
#                          Performer  year  \
# 0                            Kesha  2010
# 1                            Kesha  2010
# 2                            Kesha  2010
# 3                  Lady Antebellum  2010
# 4                  Lady Antebellum  2010
# ...                            ...   ...
# 2297  Travis Scott Featuring Drake  2023
# 2298       Latto Featuring Cardi B  2023
# 2299                     Lady Gaga  2023
# 2300                     Lady Gaga  2023
# 2301                 Lainey Wilson  2023
#
#                                                  lyrics  \
# 0     Wake up in the morning feelin' like P. Diddy (...
# 1     Wake up in the morning feelin' like P. Diddy (...
# 2     Wake up in the morning feelin' like P. Diddy (...
# 3     Picture perfect memories, scattered all around...
# 4     Picture perfect memories, scattered all around...
# ...                                                 ...
# 2297                                                NaN
# 2298                                                NaN
# 2299  Money\n ♪\n Oh\n Love is just a history that t...
# 2300  Money\n ♪\n Oh\n Love is just a history that t...
# 2301  It was right after senior year\n Just before t...
#
#                                           spotify_genre  danceability  energy  \
# 0                                                   NaN         0.755   0.837
# 1                                                   NaN         0.755   0.832
# 2                                                   NaN         0.737   0.839
# 3     ['contemporary country', 'country', 'country d...         0.588   0.724
# 4     ['contemporary country', 'country', 'country d...         0.581   0.717
# ...                                                 ...           ...     ...
# 2297                                                NaN           NaN     NaN
# 2298                                                NaN           NaN     NaN
# 2299                                                NaN         0.584   0.638
# 2300                                                NaN         0.584   0.638
# 2301                                                NaN         0.739   0.413
#
#       key  loudness mode  speechiness  acousticness  instrumentalness  \
# 0       2    -2.718    0       0.1420        0.0991          0.000000
# 1       2    -2.741    0       0.1160        0.0746          0.000001
# 2       2    -2.028    0       0.1700        0.1030          0.000000
# 3       4    -4.379    1       0.0315        0.0348          0.000095
# 4       4    -4.433    1       0.0318        0.0298          0.000186
# ...   ...       ...  ...          ...           ...               ...
# 2297  NaN       NaN  NaN          NaN           NaN               NaN
# 2298  NaN       NaN  NaN          NaN           NaN               NaN
# 2299    9    -6.437    0       0.0302        0.0134          0.000003
# 2300    9    -6.437    0       0.0302        0.0134          0.000003
# 2301    1    -6.709    1       0.0282        0.4700          0.000025
#
#       liveness  valence    tempo  duration_ms_new
# 0        0.289    0.714  120.028         199693.0
# 1        0.291    0.735  120.032         199693.0
# 2        0.319    0.718  120.042         200187.0
# 3        0.239    0.377  107.986         236787.0
# 4        0.243    0.316  107.884         236440.0
# ...        ...      ...      ...              ...
# 2297       NaN      NaN      NaN              NaN
# 2298       NaN      NaN      NaN              NaN
# 2299     0.101    0.456   99.970         244760.0
# 2300     0.101    0.456   99.970         244760.0
# 2301     0.131    0.649  139.921         208853.0
#
# [2302 rows x 18 columns]

# %%
# drop unneeded columns
df_kaggle_3.drop(columns = ['ranking', 'songurl', 'titletext', 'url', 
                            'uri', 'type', 'id', 'track_href', 'analysis_url',
                            'time_signature'], inplace = True)
df_kaggle_3
# Out:
#                       song      band_singer  year  \
# 0                  Breathe       Faith Hill  2000
# 1                   Smooth          Santana  2000
# 2                   Smooth       Rob Thomas  2000
# 3              Maria Maria          Santana  2000
# 4              Maria Maria  The Product G&B  2000
# ...                    ...              ...   ...
# 3392  Watermelon Moonshine    Lainey Wilson  2023
# 3393           Cheerleader              OMI  2015
# 3394           Felix Jaehn              OMI  2015
# 3395                 Waves         Mr Probz  2015
# 3396          Robin Schulz         Mr Probz  2015
#
#                                                  lyrics  danceability  energy  \
# 0     I can feel the magic floating in the air\nBein...         0.529   0.496
# 1     Man, it's a hot one\nLike seven inches from th...         0.609   0.923
# 2     Man, it's a hot one\nLike seven inches from th...         0.590   0.637
# 3     Ladies and gents, turn up your sound systems\n...         0.777   0.601
# 4     Turn up this sound system\nTo the sound of Car...           NaN     NaN
# ...                                                 ...           ...     ...
# 3392  It was right after senior year\nJust before th...           NaN     NaN
# 3393  When I need motivation\nMy one solution is my ...           NaN     NaN
# 3394  When I need motivation\nMy one solution is my ...           NaN     NaN
# 3395  My face above the water\nMy feet can't touch t...           NaN     NaN
# 3396  Hustle Gang over everythin'\nYeah, uh-huh\n(Dr...           NaN     NaN
#
#       key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0     7.0    -9.007   1.0       0.0290       0.17300          0.000000
# 1     9.0    -3.908   1.0       0.0338       0.16000          0.000005
# 2     9.0    -9.171   1.0       0.0301       0.00225          0.807000
# 3     2.0    -5.931   1.0       0.1260       0.04060          0.002010
# 4     NaN       NaN   NaN          NaN           NaN               NaN
# ...   ...       ...   ...          ...           ...               ...
# 3392  NaN       NaN   NaN          NaN           NaN               NaN
# 3393  NaN       NaN   NaN          NaN           NaN               NaN
# 3394  NaN       NaN   NaN          NaN           NaN               NaN
# 3395  NaN       NaN   NaN          NaN           NaN               NaN
# 3396  NaN       NaN   NaN          NaN           NaN               NaN
#
#       liveness  valence    tempo  duration_ms
# 0       0.2510    0.278  136.859     250547.0
# 1       0.2950    0.961  115.996     294987.0
# 2       0.2990    0.724  115.983     244924.0
# 3       0.0348    0.680   97.911     261973.0
# 4          NaN      NaN      NaN          NaN
# ...        ...      ...      ...          ...
# 3392       NaN      NaN      NaN          NaN
# 3393       NaN      NaN      NaN          NaN
# 3394       NaN      NaN      NaN          NaN
# 3395       NaN      NaN      NaN          NaN
# 3396       NaN      NaN      NaN          NaN
#
# [3397 rows x 16 columns]

# %%
# do another merge
merged_df_3 = merged_df_2.merge(df_kaggle_3, left_on=['name', 'year'], right_on= ['song', 'year'], 
                how = 'left', suffixes=['_df2', '_df3'])
merged_df_3
# Out:
#                           name                    artists  \
# 0                      TiK ToK                      Kesha
# 1                      TiK ToK                      Kesha
# 2                      TiK ToK                      Kesha
# 3                 Need You Now            Lady Antebellum
# 4                 Need You Now            Lady Antebellum
# ...                        ...                        ...
# 2865                  Meltdown  ['Travis Scott', 'Drake']
# 2866  Put It On Da Floor Again       ['Latto', 'Cardi B']
# 2867               Bloody Mary                  Lady Gaga
# 2868               Bloody Mary                  Lady Gaga
# 2869      Watermelon Moonshine              Lainey Wilson
#
#                          Performer  year  \
# 0                            Kesha  2010
# 1                            Kesha  2010
# 2                            Kesha  2010
# 3                  Lady Antebellum  2010
# 4                  Lady Antebellum  2010
# ...                            ...   ...
# 2865  Travis Scott Featuring Drake  2023
# 2866       Latto Featuring Cardi B  2023
# 2867                     Lady Gaga  2023
# 2868                     Lady Gaga  2023
# 2869                 Lainey Wilson  2023
#
#                                              lyrics_df2  \
# 0     Wake up in the morning feelin' like P. Diddy (...
# 1     Wake up in the morning feelin' like P. Diddy (...
# 2     Wake up in the morning feelin' like P. Diddy (...
# 3     Picture perfect memories, scattered all around...
# 4     Picture perfect memories, scattered all around...
# ...                                                 ...
# 2865                                                NaN
# 2866                                                NaN
# 2867  Money\n ♪\n Oh\n Love is just a history that t...
# 2868  Money\n ♪\n Oh\n Love is just a history that t...
# 2869  It was right after senior year\n Just before t...
#
#                                           spotify_genre  danceability_df2  \
# 0                                                   NaN             0.755
# 1                                                   NaN             0.755
# 2                                                   NaN             0.737
# 3     ['contemporary country', 'country', 'country d...             0.588
# 4     ['contemporary country', 'country', 'country d...             0.581
# ...                                                 ...               ...
# 2865                                                NaN               NaN
# 2866                                                NaN               NaN
# 2867                                                NaN             0.584
# 2868                                                NaN             0.584
# 2869                                                NaN             0.739
#
#       energy_df2 key_df2  loudness_df2  ... key_df3  loudness_df3  mode_df3  \
# 0          0.837       2        -2.718  ...     NaN           NaN       NaN
# 1          0.832       2        -2.741  ...     NaN           NaN       NaN
# 2          0.839       2        -2.028  ...     NaN           NaN       NaN
# 3          0.724       4        -4.379  ...     NaN           NaN       NaN
# 4          0.717       4        -4.433  ...     NaN           NaN       NaN
# ...          ...     ...           ...  ...     ...           ...       ...
# 2865         NaN     NaN           NaN  ...     NaN           NaN       NaN
# 2866         NaN     NaN           NaN  ...     NaN           NaN       NaN
# 2867       0.638       9        -6.437  ...     NaN           NaN       NaN
# 2868       0.638       9        -6.437  ...     NaN           NaN       NaN
# 2869       0.413       1        -6.709  ...     NaN           NaN       NaN
#
#       speechiness_df3  acousticness_df3  instrumentalness_df3  liveness_df3  \
# 0                 NaN               NaN                   NaN           NaN
# 1                 NaN               NaN                   NaN           NaN
# 2                 NaN               NaN                   NaN           NaN
# 3                 NaN               NaN                   NaN           NaN
# 4                 NaN               NaN                   NaN           NaN
# ...               ...               ...                   ...           ...
# 2865              NaN               NaN                   NaN           NaN
# 2866              NaN               NaN                   NaN           NaN
# 2867              NaN               NaN                   NaN           NaN
# 2868              NaN               NaN                   NaN           NaN
# 2869              NaN               NaN                   NaN           NaN
#
#       valence_df3 tempo_df3 duration_ms
# 0             NaN       NaN         NaN
# 1             NaN       NaN         NaN
# 2             NaN       NaN         NaN
# 3             NaN       NaN         NaN
# 4             NaN       NaN         NaN
# ...           ...       ...         ...
# 2865          NaN       NaN         NaN
# 2866          NaN       NaN         NaN
# 2867          NaN       NaN         NaN
# 2868          NaN       NaN         NaN
# 2869          NaN       NaN         NaN
#
# [2870 rows x 33 columns]

# %%
# combine audio feature columns with combine first
features = [
    'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
    'lyrics'
]

# loop through the featyres
for feature in features:
    merged_df_3[feature] = merged_df_3[f'{feature}_df2'].combine_first(merged_df_3[f'{feature}_df3'])

# some additional columns that don't follow the pattern
merged_df_3['duration_ms'] = merged_df_3['duration_ms_new'].combine_first(merged_df_3['duration_ms'])

merged_df_3.drop(columns = ['danceability_df2',
       'energy_df2', 'key_df2', 'loudness_df2', 'mode_df2', 'speechiness_df2',
       'acousticness_df2', 'instrumentalness_df2', 'liveness_df2',
       'valence_df2', 'tempo_df2', 'duration_ms_new', 'danceability_df3',
       'energy_df3', 'key_df3', 'loudness_df3', 'mode_df3', 'speechiness_df3',
       'acousticness_df3', 'instrumentalness_df3', 'liveness_df3',
       'valence_df3', 'tempo_df3', 'lyrics_df2', 'lyrics_df3', 'song', 'band_singer'], inplace = True)

merged_df_3
# Out:
#                           name                    artists  \
# 0                      TiK ToK                      Kesha
# 1                      TiK ToK                      Kesha
# 2                      TiK ToK                      Kesha
# 3                 Need You Now            Lady Antebellum
# 4                 Need You Now            Lady Antebellum
# ...                        ...                        ...
# 2865                  Meltdown  ['Travis Scott', 'Drake']
# 2866  Put It On Da Floor Again       ['Latto', 'Cardi B']
# 2867               Bloody Mary                  Lady Gaga
# 2868               Bloody Mary                  Lady Gaga
# 2869      Watermelon Moonshine              Lainey Wilson
#
#                          Performer  year  \
# 0                            Kesha  2010
# 1                            Kesha  2010
# 2                            Kesha  2010
# 3                  Lady Antebellum  2010
# 4                  Lady Antebellum  2010
# ...                            ...   ...
# 2865  Travis Scott Featuring Drake  2023
# 2866       Latto Featuring Cardi B  2023
# 2867                     Lady Gaga  2023
# 2868                     Lady Gaga  2023
# 2869                 Lainey Wilson  2023
#
#                                           spotify_genre  duration_ms  \
# 0                                                   NaN     199693.0
# 1                                                   NaN     199693.0
# 2                                                   NaN     200187.0
# 3     ['contemporary country', 'country', 'country d...     236787.0
# 4     ['contemporary country', 'country', 'country d...     236440.0
# ...                                                 ...          ...
# 2865                                                NaN          NaN
# 2866                                                NaN          NaN
# 2867                                                NaN     244760.0
# 2868                                                NaN     244760.0
# 2869                                                NaN     208853.0
#
#       danceability  energy  key  loudness mode  speechiness  acousticness  \
# 0            0.755   0.837    2    -2.718    0       0.1420        0.0991
# 1            0.755   0.832    2    -2.741    0       0.1160        0.0746
# 2            0.737   0.839    2    -2.028    0       0.1700        0.1030
# 3            0.588   0.724    4    -4.379    1       0.0315        0.0348
# 4            0.581   0.717    4    -4.433    1       0.0318        0.0298
# ...            ...     ...  ...       ...  ...          ...           ...
# 2865           NaN     NaN  NaN       NaN  NaN          NaN           NaN
# 2866           NaN     NaN  NaN       NaN  NaN          NaN           NaN
# 2867         0.584   0.638    9    -6.437    0       0.0302        0.0134
# 2868         0.584   0.638    9    -6.437    0       0.0302        0.0134
# 2869         0.739   0.413    1    -6.709    1       0.0282        0.4700
#
#       instrumentalness  liveness  valence    tempo  \
# 0             0.000000     0.289    0.714  120.028
# 1             0.000001     0.291    0.735  120.032
# 2             0.000000     0.319    0.718  120.042
# 3             0.000095     0.239    0.377  107.986
# 4             0.000186     0.243    0.316  107.884
# ...                ...       ...      ...      ...
# 2865               NaN       NaN      NaN      NaN
# 2866               NaN       NaN      NaN      NaN
# 2867          0.000003     0.101    0.456   99.970
# 2868          0.000003     0.101    0.456   99.970
# 2869          0.000025     0.131    0.649  139.921
#
#                                                  lyrics
# 0     Wake up in the morning feelin' like P. Diddy (...
# 1     Wake up in the morning feelin' like P. Diddy (...
# 2     Wake up in the morning feelin' like P. Diddy (...
# 3     Picture perfect memories, scattered all around...
# 4     Picture perfect memories, scattered all around...
# ...                                                 ...
# 2865  \nYeah\nTensions is definitely rising\nT'd up ...
# 2866                                                NaN
# 2867  Money\n ♪\n Oh\n Love is just a history that t...
# 2868  Money\n ♪\n Oh\n Love is just a history that t...
# 2869  It was right after senior year\n Just before t...
#
# [2870 rows x 18 columns]

# %%
# drop duplicates
df_unique= merged_df_3.drop_duplicates(subset=['name', 'artists', 'year'])

# drop the bonus performer column
df_unique = df_unique.drop(columns =['Performer'])

# drop NaN for audio features, use danceability as the main representation 
# usually if it's missing one, it's missing all features
df_unique.dropna(subset=['danceability'], inplace= True)

df_unique
# Out:
#                       name                       artists  year  \
# 0                  TiK ToK                         Kesha  2010
# 3             Need You Now               Lady Antebellum  2010
# 5         Hey, Soul Sister                         Train  2010
# 7         California Gurls  ['Katy Perry', 'Snoop Dogg']  2010
# 11                     OMG        ['Usher', 'will.i.am']  2010
# ...                    ...                           ...   ...
# 2845        Last Christmas                         Wham!  2023
# 2849         Handle On You               Parker McCollum  2023
# 2861      I Wrote The Book                 Morgan Wallen  2023
# 2867           Bloody Mary                     Lady Gaga  2023
# 2869  Watermelon Moonshine                 Lainey Wilson  2023
#
#                                           spotify_genre  duration_ms  \
# 0                                                   NaN     199693.0
# 3     ['contemporary country', 'country', 'country d...     236787.0
# 5                     ['neo mellow', 'pop', 'pop rock']     216667.0
# 7                                                   NaN     234653.0
# 11    ['atl hip hop', 'dance pop', 'pop', 'pop rap',...     269493.0
# ...                                                 ...          ...
# 2845                                   ['new wave pop']     265613.0
# 2849                                                NaN     219333.0
# 2861                                                NaN     181767.0
# 2867                                                NaN     244760.0
# 2869                                                NaN     208853.0
#
#       danceability  energy  key  loudness mode  speechiness  acousticness  \
# 0            0.755   0.837    2    -2.718    0       0.1420       0.09910
# 3            0.588   0.724    4    -4.379    1       0.0315       0.03480
# 5            0.675   0.885    1    -4.432    0       0.0436       0.21700
# 7            0.788   0.753    0    -3.710    1       0.0536       0.00380
# 11           0.781   0.745  4.0    -5.810  0.0       0.0332       0.19800
# ...            ...     ...  ...       ...  ...          ...           ...
# 2845         0.748   0.692   11    -5.976    0       0.0271       0.33400
# 2849         0.588   0.931    6    -3.925    1       0.0318       0.00411
# 2861         0.692   0.808    2    -3.757    1       0.0396       0.08340
# 2867         0.584   0.638    9    -6.437    0       0.0302       0.01340
# 2869         0.739   0.413    1    -6.709    1       0.0282       0.47000
#
#       instrumentalness  liveness  valence    tempo  \
# 0             0.000000    0.2890    0.714  120.028
# 3             0.000095    0.2390    0.377  107.986
# 5             0.000000    0.0860    0.768   97.030
# 7             0.000000    0.1800    0.403  125.005
# 11            0.000011    0.3600    0.326  129.998
# ...                ...       ...      ...      ...
# 2845          0.000000    0.2890    0.875  106.612
# 2849          0.000000    0.3450    0.625  105.027
# 2861          0.000037    0.0913    0.802  143.977
# 2867          0.000003    0.1010    0.456   99.970
# 2869          0.000025    0.1310    0.649  139.921
#
#                                                  lyrics
# 0     Wake up in the morning feelin' like P. Diddy (...
# 3     Picture perfect memories, scattered all around...
# 5     Hey, hey\n Hey-hey, hey-hey\n Hey-hey, hey-hey...
# 7     Greetings loved ones\n Let's take a journey\n ...
# 11    Oh my gosh\nBaby, let me\nI did it again, so I...
# ...                                                 ...
# 2845  Ah, ah-ah, ooh-whoa\n Ah-ah\n Last Christmas, ...
# 2849  I went and bought the biggest bottle they got ...
# 2861  When it comes to\n Hitchin' the boat up\n Back...
# 2867  Money\n ♪\n Oh\n Love is just a history that t...
# 2869  It was right after senior year\n Just before t...
#
# [1132 rows x 17 columns]

# %%
# convert the artists and genre strings back into lists
df_unique['artists'] = df_unique['artists'].apply(list_eval)
df_unique['spotify_genre'] = df_unique['spotify_genre'].apply(list_eval)

# %%
# get the subset of songs missing lyrics
missing_lyrics = df_unique[df_unique['lyrics'].isnull()]
missing_lyrics
# Out:
#                            name               artists  year  \
# 15         Love The Way You Lie     [Eminem, Rihanna]  2010
# 28               Nothin' On You   [B.o.B, Bruno Mars]  2010
# 45    DJ Got Us Fallin' In Love      [Usher, Pitbull]  2010
# 50                   Sexy Chick  [David Guetta, Akon]  2010
# 64                 Just A Dream                 Nelly  2010
# ...                         ...                   ...   ...
# 2135        You Broke Me First.            Tate McRae  2021
# 2156                  Telepatia            Kali Uchis  2021
# 2226                        pov         Ariana Grande  2021
# 2319   Things A Man Oughta Know         Lainey Wilson  2021
# 2490           Sand In My Boots         Morgan Wallen  2022
#
#                                           spotify_genre  duration_ms  \
# 15              [detroit hip hop, g funk, hip hop, rap]     263373.0
# 28    [atl hip hop, dance pop, hip hop, pop, pop rap...     268320.0
# 45    [atl hip hop, dance pop, pop, pop rap, r&b, ur...     220800.0
# 50                                [dance pop, edm, pop]     194346.0
# 64    [dance pop, hip hop, pop, pop rap, rap, southe...     237800.0
# ...                                                 ...          ...
# 2135  [alt z, dance pop, electropop, pop, post-teen ...     169265.0
# 2156                               [colombian pop, pop]     160191.0
# 2226                    [dance pop, pop, post-teen pop]     201882.0
# 2319                [contemporary country, country pop]     203373.0
# 2490                             [contemporary country]     202133.0
#
#       danceability  energy   key  loudness mode  speechiness  acousticness  \
# 15           0.749   0.925  10.0    -5.034  1.0       0.2270        0.2410
# 28           0.688   0.853  10.0    -5.814  1.0       0.0493        0.3860
# 45           0.663   0.861   7.0    -3.398  0.0       0.1090        0.0338
# 50           0.809   0.562  11.0    -7.694  0.0       0.0534        0.0816
# 64           0.531   0.752   1.0    -6.161  1.0       0.0305        0.0421
# ...            ...     ...   ...       ...  ...          ...           ...
# 2135         0.667   0.373   4.0    -9.389  1.0       0.0500        0.7850
# 2156         0.653   0.524  11.0    -9.016  0.0       0.0502        0.1120
# 2226         0.487   0.534   0.0    -5.664  0.0       0.0555        0.3600
# 2319         0.659   0.683   3.0    -5.623  1.0       0.0312        0.5130
# 2490         0.403   0.537   3.0    -6.628  1.0       0.0310        0.5900
#
#       instrumentalness  liveness  valence    tempo lyrics
# 15            0.000000    0.5200   0.6410   86.989    NaN
# 28            0.000000    0.0862   0.7430  103.993    NaN
# 45            0.000000    0.0820   0.6540  119.963    NaN
# 50            0.000418    0.1050   0.7980  130.003    NaN
# 64            0.000000    0.1200   0.1030   89.917    NaN
# ...                ...       ...      ...      ...    ...
# 2135          0.000000    0.0906   0.0823  124.148    NaN
# 2156          0.000000    0.2030   0.5530   83.970    NaN
# 2226          0.000000    0.1000   0.1730  131.798    NaN
# 2319          0.000005    0.1330   0.3970  139.931    NaN
# 2490          0.000000    0.1120   0.4140   69.877    NaN
#
# [141 rows x 17 columns]

# %%
# functions to help with pulling the artist to search for lyrics

def pull_artist(artist):
    if isinstance(artist, list):
        artist_str = artist[0]
    else:
        artist_str = artist
    
    return artist_str

def search_lyrics(track, artist, genius):
    try:
        artist_str = pull_artist(artist)
        song = genius.search_song(track, artist_str)
        lyrics = song.lyrics

    except:
        return None

    return lyrics

# %%
# set up for loop to search the lyrics
genius = Genius(genius_token, timeout= 10)

tracks = missing_lyrics['name'].tolist()
artists = missing_lyrics['artists'].tolist()
new_lyrics =[]

for track, artist in zip(tracks, artists):
    lyrics = search_lyrics(track, artist, genius)
    new_lyrics.append(
        {
            'name': track,
            'artists': artist,
            'lyrics':lyrics
        }
    )

new_lyrics_df = pd.DataFrame(new_lyrics)
new_lyrics_df
# Out:
# Searching for "Love The Way You Lie" by Eminem...
# Done.
# Searching for "Nothin' On You" by B.o.B...
# Done.
# Searching for "DJ Got Us Fallin' In Love" by Usher...
# Done.
# Searching for "Sexy Chick" by David Guetta...
# Done.
# Searching for "Just A Dream" by Nelly...
# Done.
# Searching for "Like A G6" by Far*East Movement...
# Done.
# Searching for "Whataya Want From Me" by Adam Lambert...
# Done.
# Searching for "All The Right Moves" by OneRepublic...
# Done.
# Searching for "According To You" by Orianthi...
# Done.
# Searching for "Today Was A Fairytale" by Taylor Swift...
# Done.
# Searching for "King Of Anything" by Sara Bareilles...
# Done.
# Searching for "Teach Me How To Dougie" by Cali Swag District...
# Done.
# Searching for "Try Sleeping With A Broken Heart" by Alicia Keys...
# Done.
# Searching for "Moves Like Jagger" by Maroon 5...
# Done.
# Searching for "Black And Yellow" by Wiz Khalifa...
# Done.
# Searching for "Hey Baby (Drop It To The Floor)" by Pitbull...
# Done.
# Searching for "I'm On One" by DJ Khaled...
# Done.
# Searching for "Yeah 3X" by Chris Brown...
# Done.
# Searching for "Just A Dream" by Nelly...
# Done.
# Searching for "Jar Of Hearts" by Christina Perri...
# Done.
# Searching for "What The Hell" by Avril Lavigne...
# Done.
# Searching for "Written In The Stars" by Tinie Tempah...
# Done.
# Searching for "DJ Got Us Fallin' In Love" by Usher...
# Done.
# Searching for "For The First Time" by The Script...
# Done.
# Searching for "You And I" by Lady Gaga...
# Done.
# Searching for "Like A G6" by Far*East Movement...
# Done.
# Searching for "Back To December" by Taylor Swift...
# Done.
# Searching for "Cheers (Drink To That)" by Rihanna...
# Done.
# Searching for "In The Dark" by Dev...
# Done.
# Searching for "Take A Back Road" by Rodney Atkins...
# Done.
# Searching for "You And Tequila" by Kenny Chesney...
# Done.
# Searching for "Set Fire To The Rain" by Adele...
# Done.
# Searching for "Moves Like Jagger" by Maroon 5...
# Done.
# Searching for "Give Your Heart A Break" by Demi Lovato...
# Done.
# Searching for "Back In Time" by Pitbull...
# Done.
# Searching for "Pound The Alarm" by Nicki Minaj...
# Done.
# Searching for "50 Ways To Say Goodbye" by Train...
# Done.
# Searching for "Love You Like A Love Song" by Selena Gomez...
# Done.
# Searching for "Turn Up The Music" by Chris Brown...
# Done.
# Searching for "Take A Little Ride" by Jason Aldean...
# Done.
# Searching for "You Da One" by Rihanna...
# Done.
# Searching for "I Don't Want This Night To End" by Luke Bryan...
# Done.
# Searching for "Hard To Love" by Lee Brice...
# Done.
# Searching for "Somethin' 'Bout A Truck" by Kip Moore...
# Done.
# Searching for "Just Give Me A Reason" by P!nk...
# Done.
# Searching for "Wake Me Up!" by Avicii...
# Done.
# Searching for "Started From The Bottom" by Drake...
# Done.
# Searching for "Girl On Fire" by Alicia Keys...
# Done.
# Searching for "The Fox" by Ylvis...
# Done.
# Searching for "That's My Kind Of Night" by Luke Bryan...
# Done.
# Searching for "Hall Of Fame" by The Script...
# Done.
# Searching for "Next To Me" by Emeli Sande...
# Done.
# Searching for "All Of Me" by John Legend...
# Done.
# Searching for "Turn Down For What" by DJ Snake...
# Done.
# Searching for "Wake Me Up!" by Avicii...
# Done.
# Searching for "Story Of My Life" by One Direction...
# Done.
# Searching for "Drunk In Love" by Beyonce...
# Done.
# Searching for "Not A Bad Thing" by Justin Timberlake...
# Done.
# Searching for "A Sky Full Of Stars" by Coldplay...
# Done.
# Searching for "Leave The Night On" by Sam Hunt...
# Done.
# Searching for "Drunk On A Plane" by Dierks Bentley...
# Done.
# Searching for "Can't Remember To Forget You" by Shakira...
# Done.
# Searching for "Come With Me Now" by KONGOS...
# Done.
# Searching for "Stay The Night" by Zedd...
# Done.
# Searching for "Uptown Funk!" by Mark Ronson...
# Done.
# Searching for "Shut Up And Dance" by WALK THE MOON...
# Done.
# Searching for "Earned It (Fifty Shades Of Grey)" by The Weeknd...
# Done.
# Searching for "Want To Want Me" by Jason Derulo...
# Done.
# Searching for "Where Are U Now" by Skrillex...
# Done.
# Searching for "Post To Be" by Omarion...
# Done.
# Searching for "Time Of Our Lives" by Pitbull...
# Searching for "Flex (Ooh Ooh Ooh)" by Rich Homie Quan...
# Searching for "Cool For The Summer" by Demi Lovato...
# Searching for "All Eyes On You" by Meek Mill...
# Searching for "Hit The Quan" by iLoveMemphis...
# Done.
# Searching for "Kick The Dust Up" by Luke Bryan...
# Done.
# Searching for "El Perdon (Forgiveness)" by Nicky Jam...
# Done.
# Searching for "Can't Stop The Feeling!" by Justin Timberlake...
# Done.
# Searching for "I Took A Pill In Ibiza" by Mike Posner...
# Done.
# Searching for "Work From Home" by Fifth Harmony...
# Done.
# Searching for "I Hate U I Love U" by gnash...
# Done.
# Searching for "Hands To Myself" by Selena Gomez...
# Done.
# Searching for "In The Night" by The Weeknd...
# Done.
# Searching for "Sucker For Pain" by Lil Wayne...
# Done.
# Searching for "Down In The DM" by Yo Gotti...
# Done.
# Searching for "Hymn For The Weekend" by Coldplay...
# Done.
# Searching for "Side To Side" by Ariana Grande...
# Done.
# Searching for "Shape Of You" by Ed Sheeran...
# Done.
# Searching for "Despacito" by Luis Fonsi...
# Done.
# Searching for "Humble." by Kendrick Lamar...
# Done.
# Searching for "Bad And Boujee" by Migos...
# Done.
# Searching for "I'm The One" by DJ Khaled...
# Done.
# Searching for "Love On The Brain" by Rihanna...
# Done.
# Searching for "Castle On The Hill" by Ed Sheeran...
# Done.
# Searching for "Side To Side" by Ariana Grande...
# Done.
# Searching for "Can't Stop The Feeling!" by Justin Timberlake...
# Done.
# Searching for "Juju On That Beat (TZ Anthem)" by Zay Hilfigerrr...
# Done.
# Searching for "Loyalty." by Kendrick Lamar...
# Done.
# Searching for "Sign Of The Times" by Harry Styles...
# Done.
# Searching for "Water Under The Bridge" by Adele...
# Done.
# Searching for "I Get The Bag" by Gucci Mane...
# Done.
# Searching for "Meant To Be" by Bebe Rexha...
# Done.
# Searching for "Never Be The Same" by Camila Cabello...
# Done.
# Searching for "No Tears Left To Cry" by Ariana Grande...
# Done.
# Searching for "Pray For Me" by The Weeknd...
# Done.
# Searching for "Back To You" by Selena Gomez...
# Done.
# Searching for "All The Stars" by Kendrick Lamar...
# Done.
# Searching for "Love." by Kendrick Lamar...
# Done.
# Searching for "God Is A Woman" by Ariana Grande...
# Done.
# Searching for "Shape Of You" by Ed Sheeran...
# Done.
# Searching for "I Get The Bag" by Gucci Mane...
# Done.
# Searching for "Te Bote" by Casper Magico...
# Done.
# Searching for "Dancing With A Stranger" by Sam Smith...
# Done.
# Searching for "Senorita" by Shawn Mendes...
# Done.
# Searching for "Sweet But Psycho" by Ava Max...
# Done.
# Searching for "ZEZE" by Kodak Black...
# Done.
# Searching for "Money In The Grave" by Drake...
# Done.
# Searching for "Break Up With Your Girlfriend, I'm Bored" by Ariana Grande...
# Done.
# Searching for "ME!" by Taylor Swift...
# Done.
# Searching for "Murder On My Mind" by YNW Melly...
# Done.
# Searching for "When The Party's Over" by Billie Eilish...
# Done.
# Searching for "Bury A Friend" by Billie Eilish...
# Done.
# Searching for "Good As You" by Kane Brown...
# Done.
# Searching for "Talk You Out Of It" by Florida Georgia Line...
# Done.
# Searching for "Eyes On You" by Chase Rice...
# Done.
# Searching for "All To Myself" by Dan + Shay...
# Done.
# Searching for "Good As Hell" by Lizzo...
# Done.
# Searching for "Senorita" by Shawn Mendes...
# Done.
# Searching for "HIGHEST IN THE ROOM" by Travis Scott...
# Done.
# Searching for "Heart On Ice" by Rod Wave...
# Done.
# Searching for "Nobody But You" by Blake Shelton Duet With Gwen Stefani...
# Done.
# Searching for "Die From A Broken Heart" by Maddie...
# Done.
# Searching for "Hard To Forget" by Sam Hunt...
# Done.
# Searching for "P*$$y Fairy (OTW)" by Jhene Aiko...
# Done.
# Searching for "Lovin' On You" by Luke Combs...
# Done.
# Searching for "Montero (Call Me By Your Name)" by Lil Nas X...
# Done.
# Searching for "You Broke Me First." by Tate McRae...
# Done.
# Searching for "Telepatia" by Kali Uchis...
# Done.
# Searching for "pov" by Ariana Grande...
# Done.
# Searching for "Things A Man Oughta Know" by Lainey Wilson...
# Done.
# Searching for "Sand In My Boots" by Morgan Wallen...
# Done.
#                           name               artists  \
# 0         Love The Way You Lie     [Eminem, Rihanna]
# 1               Nothin' On You   [B.o.B, Bruno Mars]
# 2    DJ Got Us Fallin' In Love      [Usher, Pitbull]
# 3                   Sexy Chick  [David Guetta, Akon]
# 4                 Just A Dream                 Nelly
# ..                         ...                   ...
# 136        You Broke Me First.            Tate McRae
# 137                  Telepatia            Kali Uchis
# 138                        pov         Ariana Grande
# 139   Things A Man Oughta Know         Lainey Wilson
# 140           Sand In My Boots         Morgan Wallen
#
#                                                 lyrics
# 0    364 ContributorsTranslationsTürkçeEspañolPortu...
# 1    77 ContributorsTranslationsPortuguêsNothin’ On...
# 2    76 ContributorsDJ Got Us Fallin’ in Love Lyric...
# 3    22 ContributorsSexy Chick Lyrics[Verse: Akon]\...
# 4    74 ContributorsJust a Dream Lyrics[Chorus]\nUh...
# ..                                                 ...
# 136  94 ContributorsTranslationsDanskTürkçeEspañolP...
# 137  86 ContributorsTranslationsPortuguês日本語Deutsch...
# 138  192 ContributorsTranslationsPolskiTürkçeEspaño...
# 139  9 ContributorsThings a Man Oughta Know Lyrics[...
# 140  26 ContributorsSand in My Boots Lyrics[Verse 1...
#
# [141 rows x 3 columns]

# %%
new_lyrics_df = pd.DataFrame(new_lyrics)
new_lyrics_df
# Out:
#                           name               artists  \
# 0         Love The Way You Lie     [Eminem, Rihanna]
# 1               Nothin' On You   [B.o.B, Bruno Mars]
# 2    DJ Got Us Fallin' In Love      [Usher, Pitbull]
# 3                   Sexy Chick  [David Guetta, Akon]
# 4                 Just A Dream                 Nelly
# ..                         ...                   ...
# 136        You Broke Me First.            Tate McRae
# 137                  Telepatia            Kali Uchis
# 138                        pov         Ariana Grande
# 139   Things A Man Oughta Know         Lainey Wilson
# 140           Sand In My Boots         Morgan Wallen
#
#                                                 lyrics
# 0    364 ContributorsTranslationsTürkçeEspañolPortu...
# 1    77 ContributorsTranslationsPortuguêsNothin’ On...
# 2    76 ContributorsDJ Got Us Fallin’ in Love Lyric...
# 3    22 ContributorsSexy Chick Lyrics[Verse: Akon]\...
# 4    74 ContributorsJust a Dream Lyrics[Chorus]\nUh...
# ..                                                 ...
# 136  94 ContributorsTranslationsDanskTürkçeEspañolP...
# 137  86 ContributorsTranslationsPortuguês日本語Deutsch...
# 138  192 ContributorsTranslationsPolskiTürkçeEspaño...
# 139  9 ContributorsThings a Man Oughta Know Lyrics[...
# 140  26 ContributorsSand in My Boots Lyrics[Verse 1...
#
# [141 rows x 3 columns]

# %%
# do a quick clean to remove all the beginning bits of the text

def clean_lyric_beginning(lyric_str):
    if lyric_str == None:
        return None
    else:
        lyric = lyric_str.split("Lyrics", 1)
        clean_lyric = re.sub(r'^\[[^\]]+\]\s*', '', lyric[1].strip())
        return clean_lyric

# %%
# do some initial cleaning
new_lyrics_df['lyrics'] = new_lyrics_df['lyrics'].apply(clean_lyric_beginning)
new_lyrics_df
# Out:
#                           name               artists  \
# 0         Love The Way You Lie     [Eminem, Rihanna]
# 1               Nothin' On You   [B.o.B, Bruno Mars]
# 2    DJ Got Us Fallin' In Love      [Usher, Pitbull]
# 3                   Sexy Chick  [David Guetta, Akon]
# 4                 Just A Dream                 Nelly
# ..                         ...                   ...
# 136        You Broke Me First.            Tate McRae
# 137                  Telepatia            Kali Uchis
# 138                        pov         Ariana Grande
# 139   Things A Man Oughta Know         Lainey Wilson
# 140           Sand In My Boots         Morgan Wallen
#
#                                                 lyrics
# 0    Just gonna stand there and watch me burn?\nWel...
# 1    Beautiful girls all over the world\nI could be...
# 2    USHER, USHER, USHER\nYeah, man\n\n[Verse 1: US...
# 3    Yes, I can see her\n'Cause every girl here wan...
# 4    Uh, uh, uh (Hey)\nI was thinking 'bout her (Uh...
# ..                                                 ...
# 136  You broke me first, ah\n\n[Verse 1]\nMaybe you...
# 137  [Coro]\nQuién lo diría que se podría\nHacer el...
# 138  It's like you got superpowers\nTurn my minutes...
# 139  I can hook a trailer on a two-inch hitch\nI ca...
# 140  She asked me where I's from\nI said, "Somewher...
#
# [141 rows x 3 columns]

# %%
# merge the new lyrics back in
df_final = df_unique.merge(new_lyrics_df, on= 'name', how = 'left', suffixes=['_df1', '_df2'])
df_final
# Out:
#                       name               artists_df1  year  \
# 0                  TiK ToK                     Kesha  2010
# 1             Need You Now           Lady Antebellum  2010
# 2         Hey, Soul Sister                     Train  2010
# 3         California Gurls  [Katy Perry, Snoop Dogg]  2010
# 4                      OMG        [Usher, will.i.am]  2010
# ...                    ...                       ...   ...
# 1147        Last Christmas                     Wham!  2023
# 1148         Handle On You           Parker McCollum  2023
# 1149      I Wrote The Book             Morgan Wallen  2023
# 1150           Bloody Mary                 Lady Gaga  2023
# 1151  Watermelon Moonshine             Lainey Wilson  2023
#
#                                           spotify_genre  duration_ms  \
# 0                                                   NaN     199693.0
# 1     [contemporary country, country, country dawn, ...     236787.0
# 2                           [neo mellow, pop, pop rock]     216667.0
# 3                                                   NaN     234653.0
# 4     [atl hip hop, dance pop, pop, pop rap, r&b, ur...     269493.0
# ...                                                 ...          ...
# 1147                                     [new wave pop]     265613.0
# 1148                                                NaN     219333.0
# 1149                                                NaN     181767.0
# 1150                                                NaN     244760.0
# 1151                                                NaN     208853.0
#
#       danceability  energy  key  loudness mode  speechiness  acousticness  \
# 0            0.755   0.837    2    -2.718    0       0.1420       0.09910
# 1            0.588   0.724    4    -4.379    1       0.0315       0.03480
# 2            0.675   0.885    1    -4.432    0       0.0436       0.21700
# 3            0.788   0.753    0    -3.710    1       0.0536       0.00380
# 4            0.781   0.745  4.0    -5.810  0.0       0.0332       0.19800
# ...            ...     ...  ...       ...  ...          ...           ...
# 1147         0.748   0.692   11    -5.976    0       0.0271       0.33400
# 1148         0.588   0.931    6    -3.925    1       0.0318       0.00411
# 1149         0.692   0.808    2    -3.757    1       0.0396       0.08340
# 1150         0.584   0.638    9    -6.437    0       0.0302       0.01340
# 1151         0.739   0.413    1    -6.709    1       0.0282       0.47000
#
#       instrumentalness  liveness  valence    tempo  \
# 0             0.000000    0.2890    0.714  120.028
# 1             0.000095    0.2390    0.377  107.986
# 2             0.000000    0.0860    0.768   97.030
# 3             0.000000    0.1800    0.403  125.005
# 4             0.000011    0.3600    0.326  129.998
# ...                ...       ...      ...      ...
# 1147          0.000000    0.2890    0.875  106.612
# 1148          0.000000    0.3450    0.625  105.027
# 1149          0.000037    0.0913    0.802  143.977
# 1150          0.000003    0.1010    0.456   99.970
# 1151          0.000025    0.1310    0.649  139.921
#
#                                              lyrics_df1 artists_df2 lyrics_df2
# 0     Wake up in the morning feelin' like P. Diddy (...         NaN        NaN
# 1     Picture perfect memories, scattered all around...         NaN        NaN
# 2     Hey, hey\n Hey-hey, hey-hey\n Hey-hey, hey-hey...         NaN        NaN
# 3     Greetings loved ones\n Let's take a journey\n ...         NaN        NaN
# 4     Oh my gosh\nBaby, let me\nI did it again, so I...         NaN        NaN
# ...                                                 ...         ...        ...
# 1147  Ah, ah-ah, ooh-whoa\n Ah-ah\n Last Christmas, ...         NaN        NaN
# 1148  I went and bought the biggest bottle they got ...         NaN        NaN
# 1149  When it comes to\n Hitchin' the boat up\n Back...         NaN        NaN
# 1150  Money\n ♪\n Oh\n Love is just a history that t...         NaN        NaN
# 1151  It was right after senior year\n Just before t...         NaN        NaN
#
# [1152 rows x 19 columns]

# %%
# do a combine first
df_final['lyrics'] = df_final['lyrics_df1'].combine_first(df_final['lyrics_df2'])

# drop unneeded columns/rename the artists
df_final.drop(columns = ['lyrics_df1', 'lyrics_df2', 'artists_df2'], inplace = True)
df_final.rename(columns={'artists_df1': 'artists'}, inplace= True)

# do a duplicates drop check
df_final.drop_duplicates(subset=['name', 'year'], inplace= True)
df_final
# Out:
#                       name                   artists  year  \
# 0                  TiK ToK                     Kesha  2010
# 1             Need You Now           Lady Antebellum  2010
# 2         Hey, Soul Sister                     Train  2010
# 3         California Gurls  [Katy Perry, Snoop Dogg]  2010
# 4                      OMG        [Usher, will.i.am]  2010
# ...                    ...                       ...   ...
# 1147        Last Christmas                     Wham!  2023
# 1148         Handle On You           Parker McCollum  2023
# 1149      I Wrote The Book             Morgan Wallen  2023
# 1150           Bloody Mary                 Lady Gaga  2023
# 1151  Watermelon Moonshine             Lainey Wilson  2023
#
#                                           spotify_genre  duration_ms  \
# 0                                                   NaN     199693.0
# 1     [contemporary country, country, country dawn, ...     236787.0
# 2                           [neo mellow, pop, pop rock]     216667.0
# 3                                                   NaN     234653.0
# 4     [atl hip hop, dance pop, pop, pop rap, r&b, ur...     269493.0
# ...                                                 ...          ...
# 1147                                     [new wave pop]     265613.0
# 1148                                                NaN     219333.0
# 1149                                                NaN     181767.0
# 1150                                                NaN     244760.0
# 1151                                                NaN     208853.0
#
#       danceability  energy  key  loudness mode  speechiness  acousticness  \
# 0            0.755   0.837    2    -2.718    0       0.1420       0.09910
# 1            0.588   0.724    4    -4.379    1       0.0315       0.03480
# 2            0.675   0.885    1    -4.432    0       0.0436       0.21700
# 3            0.788   0.753    0    -3.710    1       0.0536       0.00380
# 4            0.781   0.745  4.0    -5.810  0.0       0.0332       0.19800
# ...            ...     ...  ...       ...  ...          ...           ...
# 1147         0.748   0.692   11    -5.976    0       0.0271       0.33400
# 1148         0.588   0.931    6    -3.925    1       0.0318       0.00411
# 1149         0.692   0.808    2    -3.757    1       0.0396       0.08340
# 1150         0.584   0.638    9    -6.437    0       0.0302       0.01340
# 1151         0.739   0.413    1    -6.709    1       0.0282       0.47000
#
#       instrumentalness  liveness  valence    tempo  \
# 0             0.000000    0.2890    0.714  120.028
# 1             0.000095    0.2390    0.377  107.986
# 2             0.000000    0.0860    0.768   97.030
# 3             0.000000    0.1800    0.403  125.005
# 4             0.000011    0.3600    0.326  129.998
# ...                ...       ...      ...      ...
# 1147          0.000000    0.2890    0.875  106.612
# 1148          0.000000    0.3450    0.625  105.027
# 1149          0.000037    0.0913    0.802  143.977
# 1150          0.000003    0.1010    0.456   99.970
# 1151          0.000025    0.1310    0.649  139.921
#
#                                                  lyrics
# 0     Wake up in the morning feelin' like P. Diddy (...
# 1     Picture perfect memories, scattered all around...
# 2     Hey, hey\n Hey-hey, hey-hey\n Hey-hey, hey-hey...
# 3     Greetings loved ones\n Let's take a journey\n ...
# 4     Oh my gosh\nBaby, let me\nI did it again, so I...
# ...                                                 ...
# 1147  Ah, ah-ah, ooh-whoa\n Ah-ah\n Last Christmas, ...
# 1148  I went and bought the biggest bottle they got ...
# 1149  When it comes to\n Hitchin' the boat up\n Back...
# 1150  Money\n ♪\n Oh\n Love is just a history that t...
# 1151  It was right after senior year\n Just before t...
#
# [1130 rows x 17 columns]

# %%
# write out the audio features to csv
df_final_audio_features = df_final.drop(columns = ['lyrics'])
df_final_audio_features.to_csv('audio_features.csv')

# %%
# eliminate any None in lyrics
df_final_lyrics = df_final.dropna(subset=['lyrics'])
df_final_lyrics = df_final_lyrics.drop(columns =['danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo'])
df_final_lyrics.to_csv("lyrics.csv")
