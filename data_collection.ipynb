# %%
# libraries
import pandas as pd
import numpy as np
import os
import spotipy
import billboard
from dotenv import load_dotenv
from spotipy.oauth2 import SpotifyOAuth
from lyricsgenius import Genius

# %%
# load in environment variables
load_dotenv()

spotify_id = os.getenv('SPOTIFY_CLIENT_ID')
spotify_secret = os.getenv('SPOTIFY_CLIENT_SECRET')
genius_token = os.getenv('GENIUS_TOKEN')

# %%
# call for the billboard 100s from 2010-2023
chart_data_list = []
years = ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']

for y in years:
    chart = billboard.ChartData('hot-100-songs', year=y)

    for song in chart:
        chart_data_list.append({
            'title': song.title,
            'artist': song.artist,
            'year': int(y)
        })

chart_data = pd.DataFrame(chart_data_list)
chart_data.head()
# Out:
#               title                           artist  year
# 0           TiK ToK                            Ke$ha  2010
# 1      Need You Now                  Lady Antebellum  2010
# 2  Hey, Soul Sister                            Train  2010
# 3  California Gurls  Katy Perry Featuring Snoop Dogg  2010
# 4               OMG        Usher Featuring will.i.am  2010

# %%
chart = billboard.ChartData('hot-100')
print(chart)
# Out:
# hot-100 chart from 2024-11-02
# -----------------------------
# 1. 'Love Somebody' by Morgan Wallen
# 2. 'A Bar Song (Tipsy)' by Shaboozey
# 3. 'Birds Of A Feather' by Billie Eilish
# 4. 'Die With A Smile' by Lady Gaga & Bruno Mars
# 5. 'Espresso' by Sabrina Carpenter
# 6. 'I Had Some Help' by Post Malone Featuring Morgan Wallen
# 7. 'Lose Control' by Teddy Swims
# 8. 'APT.' by ROSE & Bruno Mars
# 9. 'Taste' by Sabrina Carpenter
# 10. 'Beautiful Things' by Benson Boone
# 11. 'Good Luck, Babe!' by Chappell Roan
# 12. 'Please Please Please' by Sabrina Carpenter
# 13. 'Too Sweet' by Hozier
# 14. 'Not Like Us' by Kendrick Lamar
# 15. 'Timeless' by The Weeknd & Playboi Carti
# 16. 'I Am Not Okay' by Jelly Roll
# 17. 'Lies Lies Lies' by Morgan Wallen
# 18. 'Hot To Go!' by Chappell Roan
# 19. 'I Love You, I'm Sorry' by Gracie Abrams
# 20. 'Miles On It' by Marshmello & Kane Brown
# 21. 'Million Dollar Baby' by Tommy Richman
# 22. 'Cowgirls' by Morgan Wallen Featuring ERNEST
# 23. 'Tu Boda' by Oscar Maydon & Fuerza Regida
# 24. 'TGIF' by GloRilla
# 25. 'Stargazing' by Myles Smith
# 26. 'Pink Skies' by Zach Bryan
# 27. 'Wildflower' by Billie Eilish
# 28. 'Bed Chem' by Sabrina Carpenter
# 29. 'Whatchu Kno About Me' by GloRilla & Sexyy Red
# 30. 'Ain't No Love In Oklahoma' by Luke Combs
# 31. 'Austin' by Dasha
# 32. 'Sailor Song' by Gigi Perez
# 33. 'The Door' by Teddy Swims
# 34. '25' by Rod Wave
# 35. 'You Look Like You Love Me' by Ella Langley Featuring Riley Green
# 36. 'Who' by Jimin
# 37. 'I Can Do It With A Broken Heart' by Taylor Swift
# 38. 'Kehlani' by Jordan Adetunji
# 39. 'Saturn' by SZA
